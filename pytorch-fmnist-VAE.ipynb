# Train Epoch: 19 [57600/60000 (96%)]	Loss: 268.139191
# ====> Epoch: 19 Average loss: 255.3830
# ====> Test set loss: 258.5038
# Train Epoch: 20 [0/60000 (0%)]	Loss: 252.005798
# Train Epoch: 20 [6400/60000 (11%)]	Loss: 260.095947
# Train Epoch: 20 [12800/60000 (21%)]	Loss: 269.198578
# Train Epoch: 20 [19200/60000 (32%)]	Loss: 258.773407
# Train Epoch: 20 [25600/60000 (43%)]	Loss: 258.669037
# Train Epoch: 20 [32000/60000 (53%)]	Loss: 255.492340
# Train Epoch: 20 [38400/60000 (64%)]	Loss: 281.509888
# Train Epoch: 20 [44800/60000 (75%)]	Loss: 244.215683
# Train Epoch: 20 [51200/60000 (85%)]	Loss: 249.837311
# Train Epoch: 20 [57600/60000 (96%)]	Loss: 264.451355
# ====> Epoch: 20 Average loss: 255.7770
# ====> Test set loss: 256.6319

# %%
with torch.no_grad():
    z = torch.randn(64, 2).cuda()
    
    sample = vae.decoder(z).cpu()
    
    #plt.imshow(sample.view(28,28), cmap='gray')
    save_image(sample.view(64, 1, 28, 28), './sample_2' +'.png')

# %%
import numpy as np
from scipy.stats import norm

nx = ny = 30
x_values = torch.linspace(0.05, 0.95, nx)
y_values = torch.linspace(0.05, 0.95, ny)
 
canvas = np.empty((28*ny, 28*nx))

# %%
#manifold learning

for i, yi in enumerate(x_values):
    for j, xi in enumerate(y_values):
        z_mu = torch.tensor(np.array([[norm.ppf(xi), norm.ppf(yi)]]).astype('float32'))
        x_mean = vae.decoder(z_mu.cuda()).cpu().detach().numpy()
        
        canvas[(nx-i-1)*28:(nx-i)*28, j*28:(j+1)*28] = x_mean[0].reshape(28, 28)
        
plt.figure(figsize=(8, 10))
plt.imshow(canvas, origin="upper", cmap="gray")
plt.tight_layout()

# %%
test_x.size()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-6c379d388c5e> in <module>()
# ----> 1 test_x.size()
#
# NameError: name 'test_x' is not defined

# %%
test_y.size()
# Out:
# torch.Size([10000])

# %%
import torchvision

test_data = torchvision.datasets.FashionMNIST(root='./data', train=False)

# %%
test_data
# Out:
# Dataset FashionMNIST
#     Number of datapoints: 10000
#     Root location: ./data
#     Split: Test

# %%
test_xx = test_data.test_data
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:60: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")

# %%
test_xx.size()
# Out:
# torch.Size([10000, 28, 28])

# %%
test_xx1 = test_xx.reshape(10000,784).float()

# %%
z_mean1,_ = vae.encoder(test_xx1.cuda())
z_mean1 = z_mean1.cpu().detach().numpy()

# %%
y_test = test_data.test_labels
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:50: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")

# %%
plt.figure(figsize=(12, 10))
plt.scatter(z_mean1[:, 0], z_mean1[:, 1], c=y_test)
plt.colorbar()
plt.xlabel("Dimension 1")
plt.ylabel("Dimension 2")

#labels_map = {0 : 'T-Shirt', 1 : 'Trouser', 2 : 'Pullover', 3 : 'Dress', 4 : 'Coat', 5 : 'Sandal', 6 : 'Shirt',
              7 : 'Sneaker', 8 : 'Bag', 9 : 'Ankle Boot'};
# Out:
# Text(0, 0.5, 'Dimension 2')

# %%
for i,data in enumerate(test_loader,0):
    inputs = data[0]
    labels = data[1]

# %%
import torchvision
import numpy as np

def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.detach().numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
imshow(torchvision.utils.make_grid(inputs.cpu()))
#print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(16)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-b4b0e349ca98> in <module>()
#       1 imshow(torchvision.utils.make_grid(inputs.cpu()))
# ----> 2 print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(8)))
#
# <ipython-input-24-b4b0e349ca98> in <genexpr>(.0)
#       1 imshow(torchvision.utils.make_grid(inputs.cpu()))
# ----> 2 print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(8)))
#
# NameError: name 'classes' is not defined

# %%
inputs.size()
inputs = inputs.reshape(16,784)

# %%
inputs = inputs.cuda()

h_1 = vae.encoder(inputs)

z_2 = vae.sampling(h_1[0],h_1[1])

z_2.size()

sample_2 = vae.decoder(z_2).cpu()
sample_2.size()
# Out:
# torch.Size([16, 784])

# %%
sample_2 = sample_2.reshape(16,1,28,28)

# %%
imshow(torchvision.utils.make_grid(sample_2.cpu()))
